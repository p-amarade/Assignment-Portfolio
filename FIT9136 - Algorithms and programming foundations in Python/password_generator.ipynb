# %%
def signature_password () :
    
        #Enter full name
        name = input("Enter your full name: ")
        
        #Checking the name not contain digit,not empty and have at least 3 character
        if any(charName.isalpha() or  charName.isdigit() for charName in name ) == True :
            if any(charName.isdigit() for charName in name) == False:
                if len(name) >= 3 :
                    FirstThreeLettersofName = name[0:3]
                else:
                    print("Full name should have at least 3 character")
                    return                
            else :
                print("Please input your full name without number")
                return
        else:
            print("Please input your full name again")
            return

        
        
        #Enter Date_Of_Birth           
        dob = input("Enter your date of birth in format DD/MM/YYYY: ")
        
        #Checking the format DD/MM/YYYY
        try:
            days,month,year = dob.split("/")
        except:
            print("Please input your date of birth in correct format: DD/MM/YYYY" )
            return        
        if len(days) == 2 :
            if len(month) == 2:
                if len(year) == 4 :
                    days = int(days)
                    month = int(month)
                    year = int(year)
                    LastYear = dob[-2:]
        else:
            print("Please input your date of birth in correct format: DD/MM/YYYY" )
            return      
        
               
        #Checking date in month
        if month in [1,3,5,7,8,10,12] and days <= 31 :
            Day = dob[0:2]
            Month = dob[3:5]
        elif month in [4,6,9,11] and days <= 30:
            Day = dob[0:2]
            Month = dob[3:5]     
        elif month in [2] and days <= 29:
            Day = dob[0:2]
            Month = dob[3:5]              
        else:
            print('Your input for date of birth is incorrect. Please recheck your input')
            return    

                
        #Country
        country = input("Enter your country of origin: ")      
        #Checking the Country not contain digit ,not empty and have at least 2 character
        if any(charCountry.isalpha() or  charCountry.isdigit() for charCountry in country ) == True :
            if any(charCountry.isdigit() for charCountry in country) == False:
                if len(country) >= 2 :
                    LastTwoLetterofCountry = country[-2:]
                    #Print password in format
                    print("Your password:" + LastYear+FirstThreeLettersofName.lower()+Day+LastTwoLetterofCountry.upper()+Month) 
                else:
                    print('Your country of origin should have at least 2 character')
                    return      
            else:
                print("Please input your country of origin without number")
                return      
        else:
            print("Please input your country of origin again")
            return    
            
        
    
signature_password()
# Out:
# Enter your full name: Amarade
# Enter your date of birth in format DD/MM/YYYY: 03/07/1990
# Enter your country of origin: Thailand
# Your password:90ama03ND07
