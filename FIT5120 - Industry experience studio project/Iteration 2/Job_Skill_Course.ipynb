# %%
import pandas as pd
#Loading the dataset
df_softskill = pd.read_excel('Australian Skills Classification - November 2022_1.xlsx', sheet_name='Core competencies')
df_Occupations = pd.read_excel('004-victorianvetcoursesdata.xlsx', sheet_name='Occupations')

# %%
#Filtering the ANZSCO Code
df_softskill = df_softskill[df_softskill['ANZSCO Code'].isin(df_Occupations['ANZSCO'].values)]
#Sort soft skill by score
df_softskill = df_softskill.sort_values(by=['Score'], ascending=[False])
#Show only needed column
df_softskill = df_softskill.loc[:, ['ANZSCO Code', 'Core Competency']]

# %%
# Add a new column for the competency number within each ANZSCO Title
df_softskill['index'] = df_softskill.groupby('ANZSCO Code').cumcount() + 1

# Pivot the table to create a new column for each competency
df_softskill = df_softskill.pivot(index='ANZSCO Code', columns='index', values='Core Competency')

# Rename the columns to match the original data
df_softskill = df_softskill.rename(columns={
    1: 'Softskill1',
    2: 'Softskill2',
    3: 'Softskill3',
    4: 'Softskill4',
    5: 'Softskill5'})

# Reset the index to make ANZSCO Title a column again
df_softskill = df_softskill.reset_index()
df_softskill = df_softskill.iloc[:, 0:6]

# %%
#Loading the dataset
df_Occupations_desc = pd.read_excel('Australian Skills Classification - November 2022_1.xlsx', sheet_name='Occupation descriptions')
#Select needed column
df_Occupations_desc = df_Occupations_desc[['ANZSCO Code', 'ANZSCO Title', 'ANZSCO Description']]
#Filtering the ANZSCO Code
df_Occupations_desc = df_Occupations_desc[df_Occupations_desc['ANZSCO Code'].isin(df_softskill['ANZSCO Code'].values)]
#Remove duplicate data
df_Occupations_desc = df_Occupations_desc.drop_duplicates(subset=['ANZSCO Code'])

# %%
#Merge dataset to for column ANZSCO Title ,ANZSCO Description with Top5 softskill
merged_df = df_Occupations_desc.merge(df_softskill, how='left', on='ANZSCO Code')
merged_df = merged_df.iloc[:, 0:9]
merged_df
# Out:
#      ANZSCO Code                                       ANZSCO Title  \
# 0         131112                        Sales and Marketing Manager
# 1         132111                         Corporate Services Manager
# 2         132311                             Human Resource Manager
# 3         133512                 Production Manager (Manufacturing)
# 4         133513                        Production Manager (Mining)
# ..           ...                                                ...
# 264       899415                                        Tyre Fitter
# 265       899511                                Printer's Assistant
# 266       899611                     Recycling or Rubbish Collector
# 267       899911                                   Bicycle Mechanic
# 268       899914  Electrical or Telecommunications Trades Assistant
#
#                                     ANZSCO Description  \
# 0    Plans, organises, directs, controls and coordi...
# 1    Plans, organises, directs, controls and coordi...
# 2    Plans, organises, directs, controls and coordi...
# 3    Plans, organises, directs, controls and coordi...
# 4    Plans, organises, directs, controls and coordi...
# ..                                                 ...
# 264  Fits, repairs and replaces tyres on motor vehi...
# 265  Performs routine tasks in the production of pr...
# 266  Collects household, commercial and industrial ...
# 267  Repairs and adjusts bicycles, and assembles bi...
# 268  Assists Electrotechnology and Telecommunicatio...
#
#                     Softskill1                 Softskill2  \
# 0      Planning and organising  Initiative and innovation
# 1    Initiative and innovation    Planning and organising
# 2      Planning and organising                   Teamwork
# 3                     Teamwork    Planning and organising
# 4      Planning and organising  Initiative and innovation
# ..                         ...                        ...
# 264  Initiative and innovation    Planning and organising
# 265  Initiative and innovation                    Reading
# 266  Initiative and innovation    Planning and organising
# 267                   Teamwork    Planning and organising
# 268  Initiative and innovation                   Teamwork
#
#                     Softskill3          Softskill4          Softskill5
# 0                      Reading             Writing            Teamwork
# 1                      Writing  Oral communication             Reading
# 2    Initiative and innovation             Reading             Writing
# 3    Initiative and innovation             Writing  Oral communication
# 4                     Teamwork            Learning             Reading
# ..                         ...                 ...                 ...
# 264                   Teamwork            Learning     Problem solving
# 265    Planning and organising  Oral communication            Learning
# 266                   Teamwork             Writing             Reading
# 267  Initiative and innovation  Oral communication     Problem solving
# 268    Planning and organising  Oral communication             Reading
#
# [269 rows x 8 columns]

# %%
#Loading the dataset
df_techskill = pd.read_excel('Australian Skills Classification - November 2022_1.xlsx', sheet_name='Technology tools')
#Select needed column
df_techskill = df_techskill[['ANZSCO Code', 'Technology Tool', 'Technology Tool ID']]
#Filtering the ANZSCO Code
df_techskill = df_techskill[df_techskill['ANZSCO Code'].isin(merged_df['ANZSCO Code'].values)]

# %%
# Add a new column for the competency number within each ANZSCO Title
df_techskill['index'] = df_techskill.groupby('ANZSCO Code').cumcount() + 1

# Pivot the table to create a new column for each Techskill
df_techskill_final = df_techskill.pivot(index='ANZSCO Code', columns='index', values='Technology Tool')

# Rename the columns to match the original data
df_techskill_final = df_techskill_final.rename(columns={
    1: 'Techskill1',
    2: 'Techskill2',
    3: 'Techskill3',
})

# Reset the index to make ANZSCO Title a column again
df_techskill_final = df_techskill_final.reset_index()

# %%
#Select needed column
df_techskill_final = df_techskill_final.iloc[:, 0:4]
#Merge dataset to for Top3 tech skill
merged_df = pd.merge(merged_df, df_techskill_final, how='left', on='ANZSCO Code')
merged_df
# Out:
#      ANZSCO Code                                       ANZSCO Title  \
# 0         131112                        Sales and Marketing Manager
# 1         132111                         Corporate Services Manager
# 2         132311                             Human Resource Manager
# 3         133512                 Production Manager (Manufacturing)
# 4         133513                        Production Manager (Mining)
# ..           ...                                                ...
# 264       899415                                        Tyre Fitter
# 265       899511                                Printer's Assistant
# 266       899611                     Recycling or Rubbish Collector
# 267       899911                                   Bicycle Mechanic
# 268       899914  Electrical or Telecommunications Trades Assistant
#
#                                     ANZSCO Description  \
# 0    Plans, organises, directs, controls and coordi...
# 1    Plans, organises, directs, controls and coordi...
# 2    Plans, organises, directs, controls and coordi...
# 3    Plans, organises, directs, controls and coordi...
# 4    Plans, organises, directs, controls and coordi...
# ..                                                 ...
# 264  Fits, repairs and replaces tyres on motor vehi...
# 265  Performs routine tasks in the production of pr...
# 266  Collects household, commercial and industrial ...
# 267  Repairs and adjusts bicycles, and assembles bi...
# 268  Assists Electrotechnology and Telecommunicatio...
#
#                     Softskill1                 Softskill2  \
# 0      Planning and organising  Initiative and innovation
# 1    Initiative and innovation    Planning and organising
# 2      Planning and organising                   Teamwork
# 3                     Teamwork    Planning and organising
# 4      Planning and organising  Initiative and innovation
# ..                         ...                        ...
# 264  Initiative and innovation    Planning and organising
# 265  Initiative and innovation                    Reading
# 266  Initiative and innovation    Planning and organising
# 267                   Teamwork    Planning and organising
# 268  Initiative and innovation                   Teamwork
#
#                     Softskill3          Softskill4          Softskill5  \
# 0                      Reading             Writing            Teamwork
# 1                      Writing  Oral communication             Reading
# 2    Initiative and innovation             Reading             Writing
# 3    Initiative and innovation             Writing  Oral communication
# 4                     Teamwork            Learning             Reading
# ..                         ...                 ...                 ...
# 264                   Teamwork            Learning     Problem solving
# 265    Planning and organising  Oral communication            Learning
# 266                   Teamwork             Writing             Reading
# 267  Initiative and innovation  Oral communication     Problem solving
# 268    Planning and organising  Oral communication             Reading
#
#                                            Techskill1  \
# 0                              Social media platforms
# 1           Enterprise resource planning ERP software
# 2    Document management and code versioning software
# 3           Enterprise resource planning ERP software
# 4           Enterprise resource planning ERP software
# ..                                                ...
# 264                                               NaN
# 265  Document management and code versioning software
# 266                    Facilities management software
# 267                            Social media platforms
# 268                                               NaN
#
#                                             Techskill2  \
# 0        Customer relationship management CRM software
# 1    Business intelligence and decision support sof...
# 2            Enterprise resource planning ERP software
# 3                          Project management software
# 4                          Project management software
# ..                                                 ...
# 264                                                NaN
# 265                          File storage technologies
# 266                    GPS and navigation technologies
# 267                                                NaN
# 268                                                NaN
#
#                                             Techskill3
# 0            Enterprise resource planning ERP software
# 1                          Project management software
# 2                               Social media platforms
# 3                  Video creation and editing software
# 4    Business intelligence and decision support sof...
# ..                                                 ...
# 264                                                NaN
# 265                 Graphics or photo imaging software
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
#
# [269 rows x 11 columns]

# %%
#Loading the dataset
df_tech_example = pd.read_excel('Australian Skills Classification - November 2022_1.xlsx', sheet_name='Appendix - tech tool examples')
#Filter for the most important example
df_tech_example = df_tech_example[df_tech_example['Ranking'] == 1]
#Select needed column
df_tech_example = df_tech_example[['Technology tool ID', 'Technology Tool Example']]

#Merge dataset to for Top3 tech skill example
df_tech3 = df_techskill[['ANZSCO Code','Technology Tool ID']]
df_tech3 = pd.merge(df_tech3, df_tech_example, how='left', left_on='Technology Tool ID', right_on='Technology tool ID')
df_tech3
# Out:
#       ANZSCO Code  Technology Tool ID  Technology tool ID  \
# 0          131112               31063             31063.0
# 1          131112               31015             31015.0
# 2          131112               31025             31025.0
# 3          131112               31033             31033.0
# 4          131112               31066             31066.0
# ...           ...                 ...                 ...
# 1110       741111               31039             31039.0
# 1111       832211               31036             31036.0
# 1112       832211               31036             31036.0
# 1113       839912               31036             31036.0
# 1114       851311               31054             31054.0
#
#                                 Technology Tool Example
# 0                                              Facebook
# 1                                   Salesforce software
# 2                                  SAP Business Objects
# 3                                       Adobe Photoshop
# 4                                                   SAS
# ...                                                 ...
# 1110                        Inventory tracking software
# 1111  Computerised Numerical Control (CNC) machining...
# 1112  Computerised Numerical Control (CNC) machining...
# 1113  Computerised Numerical Control (CNC) machining...
# 1114                    Credit card processing machines
#
# [1115 rows x 4 columns]

# %%
# Add a new column for the competency number within each ANZSCO Title
df_tech3['Job_index'] = df_tech3.groupby('ANZSCO Code').cumcount() + 1

# Pivot the table to create a new column for each tech skill example
df_tech3 = df_tech3.pivot(index='ANZSCO Code', columns='Job_index', values='Technology Tool Example')

# Rename the columns to match the original data
df_tech3 = df_tech3.rename(columns={
    1: 'Technology Tool Example1',
    2: 'Technology Tool Example2',
    3: 'Technology Tool Example3',
})

# Reset the index to make ANZSCO Title a column again
df_tech3 = df_tech3.reset_index()
df_tech3 = df_tech3.iloc[:, 0:4]
#Merge dataset to for Top3 tech skill example
merged_df = pd.merge(merged_df, df_tech3, how='left', on='ANZSCO Code')
merged_df
# Out:
#      ANZSCO Code                                       ANZSCO Title  \
# 0         131112                        Sales and Marketing Manager
# 1         132111                         Corporate Services Manager
# 2         132311                             Human Resource Manager
# 3         133512                 Production Manager (Manufacturing)
# 4         133513                        Production Manager (Mining)
# ..           ...                                                ...
# 264       899415                                        Tyre Fitter
# 265       899511                                Printer's Assistant
# 266       899611                     Recycling or Rubbish Collector
# 267       899911                                   Bicycle Mechanic
# 268       899914  Electrical or Telecommunications Trades Assistant
#
#                                     ANZSCO Description  \
# 0    Plans, organises, directs, controls and coordi...
# 1    Plans, organises, directs, controls and coordi...
# 2    Plans, organises, directs, controls and coordi...
# 3    Plans, organises, directs, controls and coordi...
# 4    Plans, organises, directs, controls and coordi...
# ..                                                 ...
# 264  Fits, repairs and replaces tyres on motor vehi...
# 265  Performs routine tasks in the production of pr...
# 266  Collects household, commercial and industrial ...
# 267  Repairs and adjusts bicycles, and assembles bi...
# 268  Assists Electrotechnology and Telecommunicatio...
#
#                     Softskill1                 Softskill2  \
# 0      Planning and organising  Initiative and innovation
# 1    Initiative and innovation    Planning and organising
# 2      Planning and organising                   Teamwork
# 3                     Teamwork    Planning and organising
# 4      Planning and organising  Initiative and innovation
# ..                         ...                        ...
# 264  Initiative and innovation    Planning and organising
# 265  Initiative and innovation                    Reading
# 266  Initiative and innovation    Planning and organising
# 267                   Teamwork    Planning and organising
# 268  Initiative and innovation                   Teamwork
#
#                     Softskill3          Softskill4          Softskill5  \
# 0                      Reading             Writing            Teamwork
# 1                      Writing  Oral communication             Reading
# 2    Initiative and innovation             Reading             Writing
# 3    Initiative and innovation             Writing  Oral communication
# 4                     Teamwork            Learning             Reading
# ..                         ...                 ...                 ...
# 264                   Teamwork            Learning     Problem solving
# 265    Planning and organising  Oral communication            Learning
# 266                   Teamwork             Writing             Reading
# 267  Initiative and innovation  Oral communication     Problem solving
# 268    Planning and organising  Oral communication             Reading
#
#                                            Techskill1  \
# 0                              Social media platforms
# 1           Enterprise resource planning ERP software
# 2    Document management and code versioning software
# 3           Enterprise resource planning ERP software
# 4           Enterprise resource planning ERP software
# ..                                                ...
# 264                                               NaN
# 265  Document management and code versioning software
# 266                    Facilities management software
# 267                            Social media platforms
# 268                                               NaN
#
#                                             Techskill2  \
# 0        Customer relationship management CRM software
# 1    Business intelligence and decision support sof...
# 2            Enterprise resource planning ERP software
# 3                          Project management software
# 4                          Project management software
# ..                                                 ...
# 264                                                NaN
# 265                          File storage technologies
# 266                    GPS and navigation technologies
# 267                                                NaN
# 268                                                NaN
#
#                                             Techskill3  \
# 0            Enterprise resource planning ERP software
# 1                          Project management software
# 2                               Social media platforms
# 3                  Video creation and editing software
# 4    Business intelligence and decision support sof...
# ..                                                 ...
# 264                                                NaN
# 265                 Graphics or photo imaging software
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
#
#                               Technology Tool Example1  \
# 0                                             Facebook
# 1                                 SAP Business Objects
# 2                                                  Git
# 3                                 SAP Business Objects
# 4                                 SAP Business Objects
# ..                                                 ...
# 264                                                NaN
# 265                                                Git
# 266  Computerised Maintenance Management System sof...
# 267                                           Facebook
# 268                                                NaN
#
#                   Technology Tool Example2 Technology Tool Example3
# 0                      Salesforce software     SAP Business Objects
# 1                     SAP Business Objects     Microsoft SharePoint
# 2                     SAP Business Objects                 Facebook
# 3                     Microsoft SharePoint      Adobe After Effects
# 4                     Microsoft SharePoint     SAP Business Objects
# ..                                     ...                      ...
# 264                                    NaN                      NaN
# 265                Cloud storage solutions          Adobe Photoshop
# 266  Global Positioning System GPS devices                      NaN
# 267                                    NaN                      NaN
# 268                                    NaN                      NaN
#
# [269 rows x 14 columns]

# %%
#Loading the dataset
df_Course_occ = pd.read_excel('004-victorianvetcoursesdata.xlsx', sheet_name='Course_Occupation')
df_Course_name = pd.read_excel('004-victorianvetcoursesdata.xlsx', sheet_name='Courses')

# %%
#Filtering the ANZSCO Code
df_Course_occ = df_Course_occ[df_Course_occ['anzsco'].isin(merged_df['ANZSCO Code'].values)]
df_Course_name = df_Course_name.rename(columns={'ID': 'Course ID'})
df_Course_merged = pd.merge(df_Course_occ, df_Course_name, how='left', on='Course ID')
#Merge course name and entry requirement
df_Course_merged = df_Course_merged[['anzsco', 'Course ID', 'Course Title','entry_requirements']]
df_Course_merged
# Out:
#      anzsco  Course ID                                       Course Title  \
# 0    362411         31                   Certificate II in Retail Nursery
# 1    362411         52              Certificate III in Production Nursery
# 2    362411         53                  Certificate III in Retail Nursery
# 3    234314         55  Certificate III in Conservation and Land Manag...
# 4    721111         67      Certificate III in Rural Machinery Operations
# ..      ...        ...                                                ...
# 750  721211      11382              Certificate III in Civil Construction
# 751  321214      11383  Certificate III in Outdoor Power Equipment Tec...
# 752  234711      11416  Graduate Diploma of Animal Biomechanical Medicine
# 753  241213      11516       Advanced Diploma of Rudolf Steiner Education
# 754  254411      11527  Graduate Certificate in Advising on Chronic Di...
#
#                                     entry_requirements
# 0                                 No minimum education
# 1                                 No minimum education
# 2                                 No minimum education
# 3                                 No minimum education
# 4                                 No minimum education
# ..                                                 ...
# 750                               No minimum education
# 751                               No minimum education
# 752  Bachelor of Veterinary Science, Chiropractic S...
# 753                                   Relevant Diploma
# 754  Relevant employment as a nurse (Division 1 or ...
#
# [755 rows x 4 columns]

# %%
# Add a new column for the competency number within each ANZSCO Title
df_Course_merged['index'] = df_Course_merged.groupby('anzsco').cumcount() + 1

# Pivot the table to create a new column for each Course
df_Course_name_top5 = df_Course_merged.pivot(index='anzsco', columns='index', values='Course Title')

# Rename the columns to match the original data
df_Course_name_top5 = df_Course_name_top5.rename(columns={
    1: 'Course1',
    2: 'Course2',
    3: 'Course3',
    4: 'Course4',
    5: 'Course5'
})

# Reset the index to make ANZSCO Title a column again
df_Course_name_top5 = df_Course_name_top5.reset_index()

# %%
#Merge dataset for top5 course
df_Course_name_top5 = df_Course_name_top5.iloc[:, 0:6]
df_Course_name_top5 = df_Course_name_top5.rename(columns={'anzsco': 'ANZSCO Code'})
merged_df = pd.merge(merged_df, df_Course_name_top5, how='left', on='ANZSCO Code')
merged_df
# Out:
#      ANZSCO Code                                       ANZSCO Title  \
# 0         131112                        Sales and Marketing Manager
# 1         132111                         Corporate Services Manager
# 2         132311                             Human Resource Manager
# 3         133512                 Production Manager (Manufacturing)
# 4         133513                        Production Manager (Mining)
# ..           ...                                                ...
# 264       899415                                        Tyre Fitter
# 265       899511                                Printer's Assistant
# 266       899611                     Recycling or Rubbish Collector
# 267       899911                                   Bicycle Mechanic
# 268       899914  Electrical or Telecommunications Trades Assistant
#
#                                     ANZSCO Description  \
# 0    Plans, organises, directs, controls and coordi...
# 1    Plans, organises, directs, controls and coordi...
# 2    Plans, organises, directs, controls and coordi...
# 3    Plans, organises, directs, controls and coordi...
# 4    Plans, organises, directs, controls and coordi...
# ..                                                 ...
# 264  Fits, repairs and replaces tyres on motor vehi...
# 265  Performs routine tasks in the production of pr...
# 266  Collects household, commercial and industrial ...
# 267  Repairs and adjusts bicycles, and assembles bi...
# 268  Assists Electrotechnology and Telecommunicatio...
#
#                     Softskill1                 Softskill2  \
# 0      Planning and organising  Initiative and innovation
# 1    Initiative and innovation    Planning and organising
# 2      Planning and organising                   Teamwork
# 3                     Teamwork    Planning and organising
# 4      Planning and organising  Initiative and innovation
# ..                         ...                        ...
# 264  Initiative and innovation    Planning and organising
# 265  Initiative and innovation                    Reading
# 266  Initiative and innovation    Planning and organising
# 267                   Teamwork    Planning and organising
# 268  Initiative and innovation                   Teamwork
#
#                     Softskill3          Softskill4          Softskill5  \
# 0                      Reading             Writing            Teamwork
# 1                      Writing  Oral communication             Reading
# 2    Initiative and innovation             Reading             Writing
# 3    Initiative and innovation             Writing  Oral communication
# 4                     Teamwork            Learning             Reading
# ..                         ...                 ...                 ...
# 264                   Teamwork            Learning     Problem solving
# 265    Planning and organising  Oral communication            Learning
# 266                   Teamwork             Writing             Reading
# 267  Initiative and innovation  Oral communication     Problem solving
# 268    Planning and organising  Oral communication             Reading
#
#                                            Techskill1  \
# 0                              Social media platforms
# 1           Enterprise resource planning ERP software
# 2    Document management and code versioning software
# 3           Enterprise resource planning ERP software
# 4           Enterprise resource planning ERP software
# ..                                                ...
# 264                                               NaN
# 265  Document management and code versioning software
# 266                    Facilities management software
# 267                            Social media platforms
# 268                                               NaN
#
#                                             Techskill2  \
# 0        Customer relationship management CRM software
# 1    Business intelligence and decision support sof...
# 2            Enterprise resource planning ERP software
# 3                          Project management software
# 4                          Project management software
# ..                                                 ...
# 264                                                NaN
# 265                          File storage technologies
# 266                    GPS and navigation technologies
# 267                                                NaN
# 268                                                NaN
#
#                                             Techskill3  \
# 0            Enterprise resource planning ERP software
# 1                          Project management software
# 2                               Social media platforms
# 3                  Video creation and editing software
# 4    Business intelligence and decision support sof...
# ..                                                 ...
# 264                                                NaN
# 265                 Graphics or photo imaging software
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
#
#                               Technology Tool Example1  \
# 0                                             Facebook
# 1                                 SAP Business Objects
# 2                                                  Git
# 3                                 SAP Business Objects
# 4                                 SAP Business Objects
# ..                                                 ...
# 264                                                NaN
# 265                                                Git
# 266  Computerised Maintenance Management System sof...
# 267                                           Facebook
# 268                                                NaN
#
#                   Technology Tool Example2 Technology Tool Example3  \
# 0                      Salesforce software     SAP Business Objects
# 1                     SAP Business Objects     Microsoft SharePoint
# 2                     SAP Business Objects                 Facebook
# 3                     Microsoft SharePoint      Adobe After Effects
# 4                     Microsoft SharePoint     SAP Business Objects
# ..                                     ...                      ...
# 264                                    NaN                      NaN
# 265                Cloud storage solutions          Adobe Photoshop
# 266  Global Positioning System GPS devices                      NaN
# 267                                    NaN                      NaN
# 268                                    NaN                      NaN
#
#                                                Course1  \
# 0        Diploma of Fashion and Textiles Merchandising
# 1                         Advanced Diploma of Business
# 2     Advanced Diploma of Management (Human Resources)
# 3                    Certificate IV in Food Processing
# 4             Diploma of Surface Operations Management
# ..                                                 ...
# 264  Certificate II in Automotive Tyre Servicing Te...
# 265  Certificate II in Printing and Graphic Arts (G...
# 266                Certificate III in Waste Management
# 267     Certificate III in Bicycle Workshop Operations
# 268               Certificate II in Technical Security
#
#                                                Course2  \
# 0    Advanced Diploma of Fashion and Textiles Merch...
# 1                       Advanced Diploma of Management
# 2                                                  NaN
# 3                           Diploma of Food Processing
# 4                                                  NaN
# ..                                                 ...
# 264                                                NaN
# 265  Certificate II in Printing and Graphic Arts (S...
# 266                 Certificate IV in Waste Management
# 267                                                NaN
# 268              Certificate III in Technical Security
#
#                                                Course3  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268  Certificate II in Split Air-conditioning and H...
#
#                                        Course4  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 264                                        NaN
# 265                                        NaN
# 266                                        NaN
# 267                                        NaN
# 268  Certificate II in Integrated Technologies
#
#                                                Course5
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268  Certificate II in Sustainable Energy (Career S...
#
# [269 rows x 19 columns]

# %%
# Pivot the table to create a new column for each entry_requirements
df_Course_required = df_Course_merged.pivot(index='anzsco', columns='index', values='entry_requirements')

# Rename the columns to match the original data
df_Course_required = df_Course_required.rename(columns={
    1: 'entry_requirements1',
    2: 'entry_requirements2',
    3: 'entry_requirements3',
    4: 'entry_requirements4',
    5: 'entry_requirements5'
})

# Reset the index to make ANZSCO Title a column again
df_Course_required = df_Course_required.reset_index()

# %%
#Merge dataset for top5 course entry requirements
df_Course_required = df_Course_required.iloc[:, 0:6]
df_Course_required = df_Course_required.rename(columns={'anzsco': 'ANZSCO Code'})
merged_df = pd.merge(merged_df, df_Course_required, how='left', on='ANZSCO Code')
merged_df
# Out:
#      ANZSCO Code                                       ANZSCO Title  \
# 0         131112                        Sales and Marketing Manager
# 1         132111                         Corporate Services Manager
# 2         132311                             Human Resource Manager
# 3         133512                 Production Manager (Manufacturing)
# 4         133513                        Production Manager (Mining)
# ..           ...                                                ...
# 264       899415                                        Tyre Fitter
# 265       899511                                Printer's Assistant
# 266       899611                     Recycling or Rubbish Collector
# 267       899911                                   Bicycle Mechanic
# 268       899914  Electrical or Telecommunications Trades Assistant
#
#                                     ANZSCO Description  \
# 0    Plans, organises, directs, controls and coordi...
# 1    Plans, organises, directs, controls and coordi...
# 2    Plans, organises, directs, controls and coordi...
# 3    Plans, organises, directs, controls and coordi...
# 4    Plans, organises, directs, controls and coordi...
# ..                                                 ...
# 264  Fits, repairs and replaces tyres on motor vehi...
# 265  Performs routine tasks in the production of pr...
# 266  Collects household, commercial and industrial ...
# 267  Repairs and adjusts bicycles, and assembles bi...
# 268  Assists Electrotechnology and Telecommunicatio...
#
#                     Softskill1                 Softskill2  \
# 0      Planning and organising  Initiative and innovation
# 1    Initiative and innovation    Planning and organising
# 2      Planning and organising                   Teamwork
# 3                     Teamwork    Planning and organising
# 4      Planning and organising  Initiative and innovation
# ..                         ...                        ...
# 264  Initiative and innovation    Planning and organising
# 265  Initiative and innovation                    Reading
# 266  Initiative and innovation    Planning and organising
# 267                   Teamwork    Planning and organising
# 268  Initiative and innovation                   Teamwork
#
#                     Softskill3          Softskill4          Softskill5  \
# 0                      Reading             Writing            Teamwork
# 1                      Writing  Oral communication             Reading
# 2    Initiative and innovation             Reading             Writing
# 3    Initiative and innovation             Writing  Oral communication
# 4                     Teamwork            Learning             Reading
# ..                         ...                 ...                 ...
# 264                   Teamwork            Learning     Problem solving
# 265    Planning and organising  Oral communication            Learning
# 266                   Teamwork             Writing             Reading
# 267  Initiative and innovation  Oral communication     Problem solving
# 268    Planning and organising  Oral communication             Reading
#
#                                            Techskill1  \
# 0                              Social media platforms
# 1           Enterprise resource planning ERP software
# 2    Document management and code versioning software
# 3           Enterprise resource planning ERP software
# 4           Enterprise resource planning ERP software
# ..                                                ...
# 264                                               NaN
# 265  Document management and code versioning software
# 266                    Facilities management software
# 267                            Social media platforms
# 268                                               NaN
#
#                                             Techskill2  ...  \
# 0        Customer relationship management CRM software  ...
# 1    Business intelligence and decision support sof...  ...
# 2            Enterprise resource planning ERP software  ...
# 3                          Project management software  ...
# 4                          Project management software  ...
# ..                                                 ...  ...
# 264                                                NaN  ...
# 265                          File storage technologies  ...
# 266                    GPS and navigation technologies  ...
# 267                                                NaN  ...
# 268                                                NaN  ...
#
#                                                Course1  \
# 0        Diploma of Fashion and Textiles Merchandising
# 1                         Advanced Diploma of Business
# 2     Advanced Diploma of Management (Human Resources)
# 3                    Certificate IV in Food Processing
# 4             Diploma of Surface Operations Management
# ..                                                 ...
# 264  Certificate II in Automotive Tyre Servicing Te...
# 265  Certificate II in Printing and Graphic Arts (G...
# 266                Certificate III in Waste Management
# 267     Certificate III in Bicycle Workshop Operations
# 268               Certificate II in Technical Security
#
#                                                Course2  \
# 0    Advanced Diploma of Fashion and Textiles Merch...
# 1                       Advanced Diploma of Management
# 2                                                  NaN
# 3                           Diploma of Food Processing
# 4                                                  NaN
# ..                                                 ...
# 264                                                NaN
# 265  Certificate II in Printing and Graphic Arts (S...
# 266                 Certificate IV in Waste Management
# 267                                                NaN
# 268              Certificate III in Technical Security
#
#                                                Course3  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268  Certificate II in Split Air-conditioning and H...
#
#                                        Course4  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 264                                        NaN
# 265                                        NaN
# 266                                        NaN
# 267                                        NaN
# 268  Certificate II in Integrated Technologies
#
#                                                Course5  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268  Certificate II in Sustainable Energy (Career S...
#
#                                    entry_requirements1  \
# 0                                 No minimum education
# 1    Diploma of Business or other relevant qualific...
# 2    Relevant Diploma; or relevant vocational exper...
# 3    Certificate III in Food Processing; or relevan...
# 4                                 No minimum education
# ..                                                 ...
# 264                               No minimum education
# 265                               No minimum education
# 266                               No minimum education
# 267                               No minimum education
# 268                               No minimum education
#
#                                    entry_requirements2  \
# 0        Diploma of Fashion and Textiles Merchandising
# 1    Diploma of Management; or relevant vocational ...
# 2                                                  NaN
# 3    Certificate IV in Food Processing; or relevant...
# 4                                                  NaN
# ..                                                 ...
# 264                                                NaN
# 265                               No minimum education
# 266  Certificate III in Waste Management or equivalent
# 267                                                NaN
# 268                               No minimum education
#
#                                    entry_requirements3   entry_requirements4  \
# 0                                                  NaN                   NaN
# 1                                                  NaN                   NaN
# 2                                                  NaN                   NaN
# 3                                                  NaN                   NaN
# 4                                                  NaN                   NaN
# ..                                                 ...                   ...
# 264                                                NaN                   NaN
# 265                                                NaN                   NaN
# 266                                                NaN                   NaN
# 267                                                NaN                   NaN
# 268  Entry requirements may vary among providers. P...  No minimum education
#
#       entry_requirements5
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 264                   NaN
# 265                   NaN
# 266                   NaN
# 267                   NaN
# 268  No minimum education
#
# [269 rows x 24 columns]

# %%
#Saving file as CSV
merged_df.to_csv('job_skill_course.csv', index=False)
